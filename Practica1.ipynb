# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("unclean_data1.csv",encoding='utf8')

# %%
df.shape
# Out:
# (14, 16)

# %%
df.head(14)
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.tail()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 9                    25000  301956980         321795.0
# ...

# %%
df['movie_title'].dtype
# Out:
# dtype('O')

# %%
df['num_critic_for_reviews'].dtype
# Out:
# dtype('int64')

# %%
df['duration'].dtype
# Out:
# dtype('float64')

# %%
df['DIRECTOR_facebook_likes'].dtype
# Out:
# dtype('O')

# %%
df['actor_3_facebook_likes'].dtype
# Out:
# dtype('int64')

# %%
df['ACTOR_1_facebook_likes'].dtype
# Out:
# dtype('int64')

# %%
df['gross'].dtype
# Out:
# dtype('int64')

# %%
df['num_voted_users'].dtype
# Out:
# dtype('float64')

# %%
df['Cast_Total_facebook_likes'].dtype
# Out:
# dtype('float64')

# %%
df['facenumber_in_poster'].dtype
# Out:
# dtype('float64')

# %%
df['num_user_for_reviews'].dtype
# Out:
# dtype('int64')

# %%
df['budget'].dtype
# Out:
# dtype('int64')

# %%
df['ACTOR_2_facebook_likes'].dtype
# Out:
# dtype('float64')

# %%
df['imdb_score'].dtype
# Out:
# dtype('float64')

# %%
df['title_year.1'].dtype
# Out:
# dtype('float64')

# %%
df['title_year'].dtype
# Out:
# dtype('int64')

# %%
df.drop('title_year.1',axis = 1 )
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.drop('facenumber_in_poster',axis = 1 )
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
#Titulo	es tipo caracter
#Numero_Criticas es tipo entero
#Duracion es tipo flotante
#DirLikesFB es tipo caracter
#Act3LikesFB es tipo entero
#Act1LikesFB  es tipo entero
#Ganancias es tipo flotante
#Votantes es tipo flotante
#TotalLikesFB es tipo flotante
#Vistas es tipo entero
#Presupuesto es tipo entero
#Año es tipo entero
#Act2LikesFB es tipo flotante
#Calificacion es tipo flotante

# %%
df.budget.unique()
# Out:
# array([237000000, 300000000, 245000000, 250000000, 263700000, 258000000,
#        260000000, 209000000, 200000000, 225000000], dtype=int64)

# %%
df.title_year.unique()
# Out:
# array([2009, 2007, 2015, 2012, 2010, 2016, 2006, 2008], dtype=int64)

# %%
clase_1 = df[df['title_year']=='2009']

clase_1.to_csv('Solo_clase1.csv', index=False)

# %%
clase_2 = df[df['title_year']=='2007']

clase_2.to_csv('Solo_clase2.csv', index=False)

# %%
clase_3 = df[df['title_year']=='2015']

clase_3.to_csv('Solo_clase3.csv', index=False)

# %%
clase_4 = df[df['title_year']=='2012']

clase_4.to_csv('Solo_clase4.csv', index=False)

# %%
clase_5 = df[df['title_year']=='2010']

clase_5.to_csv('Solo_clase5.csv', index=False)

# %%
clase_6 = df[df['title_year']=='2016']

clase_6.to_csv('Solo_clase6.csv', index=False)

# %%
clase_7 = df[df['title_year']=='2006']

clase_7.to_csv('Solo_clase7.csv', index=False)

# %%
clase_8 = df[df['title_year']=='2008']

clase_8.to_csv('Solo_clase8.csv', index=False)

# %%
df.rename(columns = {'movie_title':'Titulo','duration':'Duracion','num_critic_for_reviews':'Numero_Criticas','DIRECTOR_facebook_likes':'DirLikesFB','actor_3_facebook_likes':'Act3LikesFB','ACTOR_1_facebook_likes':'Act1LikesFB','gross':'Ganancias','num_voted_users':'Votantes','Cast_Total_facebook_likes':'TotalLikesFB','num_user_for_reviews':'Vistas','budget':'Presupuesto','title_year':'Año','ACTOR_2_facebook_likes':'Act2LikesFB','imdb_score':'Calificacion'})
# Out:
#                                           Titulo  Numero_Criticas  Duracion  \
# 0                                       Avatar?ÿ              723     178.0
# 1     Pirates of the Caribbean: At World's End?ÿ              302       NaN
# 2                                      Spectre?ÿ              602     148.0
# 3                        The Dark Knight Rises?ÿ              813       NaN
# 4                                  John Carter?ÿ              462     132.0
# 5                                 Spider-Man 3?ÿ              392     156.0
# 6                                      Tangled?ÿ              324       NaN
# 7                      Avengers: Age of Ultron?ÿ              635     141.0
# 8                      Avengers: Age of Ultron?ÿ              635     141.0
# 9       Harry Potter and the Half-Blood Prince?ÿ              375     153.0
# 10          Batman v Superman: Dawn of Justice?ÿ              673     183.0
# ...

# %%
#¿Para que me puede servir estas agrupaciones para la práctica siguiente?
#Para tener los datos clasificados y ordenados y poder manipularlos mejor
